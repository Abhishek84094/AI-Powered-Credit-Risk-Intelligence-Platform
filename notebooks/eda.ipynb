# %% [markdown]
# # CredPulse — AI-Powered Credit Risk Intelligence Platform
# ## Layer 1: Exploratory Data Analysis (EDA)
#
# This notebook covers:
# 1. Ingestion & Target Imbalance Audit
# 2. Demographics, Financials & External Bureau Distributions
# 3. Anomaly Analysis (`DAYS_EMPLOYED = 365243`)
# 4. 5 Core Business Insights with Visualizations

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

DATA_DIR = '../data/home-credit-default-risk'
df = pd.read_csv(os.path.join(DATA_DIR, 'application_train.csv'))
print(f'Applicants loaded: {len(df):,} rows, {len(df.columns)} columns')
df.head()

# %%
# Target distribution & class imbalance
target_counts = df['TARGET'].value_counts()
print(target_counts)
print(f'Default Rate: {df["TARGET"].mean() * 100:.2f}%')

# %%
# External source distributions
ext_cols = ['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']
df.groupby('TARGET')[ext_cols].mean()
